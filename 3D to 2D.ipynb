# %%
# %matplotlib inline

# %%
import matplotlib.pyplot
import skimage.io

# %%
data = skimage.io.imread("C:/Users/Voss/image_final_low.tif")

# %%
data.shape
# Out:
# (129L, 565L, 807L)

# %%
_, axes = matplotlib.pyplot.subplots(nrows=5, ncols=5, figsize=(12, 12))

for ax, plane in zip(axes.flatten(), data):
    ax.imshow(plane, cmap="gray")

# %%
reshaped = data.reshape(-1, data.shape[-1])

# %%
reshaped.shape
# Out:
# (72885L, 807L)

# %%
skimage.io.imshow(reshaped[:2000, :], cmap="gray")
